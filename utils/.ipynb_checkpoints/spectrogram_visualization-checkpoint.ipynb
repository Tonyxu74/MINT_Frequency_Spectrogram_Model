# %%
import scipy
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../data/train/11.npy',allow_pickle=True)

# %%
dataravel = data[0]
#print(dataravel.shape)

a = np.arange(0,data.shape[1],1)

x = np.array([])
y = np.array([])

b = np.arange(0,12)

for i in range(data.shape[1]):
    a = i*np.ones(data.shape[1])
    x = np.concatenate((x,a))
    y = np.concatenate((y,b))

#print(data)
#print(x)
#print(y)
dataravel = dataravel.flatten()
#print(dataravel)

# %%
fig, ax = plt.subplots()
h = ax.hist2d(y, x, weights=dataravel)
plt.colorbar(h[3], ax=ax)
plt.xlabel('Arbitrary Time Units', fontsize=12)
plt.ylabel('Arbitrary Frequency Units', fontsize=12)
plt.title('Relative Frequency Contributions of One Channel',fontsize=12)

fig.savefig('input_sample.png')

# %%
import csv
wavelet = np.array([])

with open('../data/raw/raw_nov-16_c3_riley_test.txt', newline='') as csvfile:
    reader = csv.reader(csvfile)
    
    i=0
    for row in reader:
        i=i+1
        if i<255:
            print(row[1])
            wavelet= np.append(wavelet,row[1])
            
            
time = np.arange(wavelet.shape[0])
            
fig = plt.plot(time,wavelet)
#plt.xlabel('Arbitrary Time Units', fontsize=12)
#plt.ylabel('Arbitrary Frequency Units', fontsize=12)
#plt.title('Relative Frequency Contributions of One Channel',fontsize=12)

plt.savefig('wavelet.png')
# Out:
#  902.99
#  901.76
#  903.55
#  902.47
#  906.54
#  902.74
#  901.47
#  901.74
#  903.93
#  906.09
#  913.94
#  914.61
#  902.94
#  908.06
#  910.36
#  905.27
#  908.06
#  906.61
#  906.85
#  898.16
#  894.49
#  893.51
#  897.20
#  898.72
#  901.31
#  904.82
#  898.27
#  901.80
#  904.55
#  898.74
#  902.43
#  901.80
#  897.89
#  893.47
#  898.45
#  899.17
#  904.42
#  903.68
#  900.86
#  904.44
#  905.42
#  907.15
#  902.74
#  907.68
#  912.82
#  902.74
#  900.53
#  904.17
#  903.77
#  901.36
#  907.77
#  913.00
#  911.37
#  899.90
#  899.90
#  897.33
#  902.85
#  903.66
#  903.17
#  898.36
#  902.27
#  900.53
#  901.31
#  900.02
#  894.99
#  891.43
#  890.67
#  894.05
#  893.20
#  892.30
#  894.74
#  898.50
#  900.98
#  897.11
#  890.18
#  901.54
#  897.11
#  892.28
#  895.41
#  899.46
#  898.83
#  900.17
#  904.42
#  897.44
#  891.86
#  901.24
#  906.43
#  901.65
#  906.88
#  906.81
#  910.48
#  914.05
#  919.37
#  915.64
#  914.43
#  915.91
#  916.78
#  916.11
#  920.29
#  919.08
# ...
